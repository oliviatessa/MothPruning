# %%
import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# make signal

# %%
timesteps = np.linspace(0, 1, num = 1000)

sig1 = np.sin(2*np.pi*15* timesteps)
y = 0.1* sig1
y2 = 0.1*np.random.randn(len(timesteps))
y3 = sig1.copy()

# %%
plt.plot(timesteps, sig)
plt.plot(timesteps, y)
plt.plot(timesteps, y2)

# %%
A = np.vstack([sig, y, y2, y3])

# %%
U, s, Vh = scipy.linalg.svd(A)

# %%
U.shape
# Out:
# (4, 4)

# %%
U
# Out:
# array([[-7.05342113e-01, -2.22299694e-03,  6.65518379e-01,
#         -2.44075499e-01],
#        [-7.05342113e-02, -2.22299694e-04,  2.76717727e-01,
#          9.58359106e-01],
#        [ 3.15164210e-03, -9.99995034e-01,  7.65897215e-17,
#          3.90990292e-16],
#        [-7.05342113e-01, -2.22299694e-03, -6.93190152e-01,
#          1.48239588e-01]])

# %%
plt.plot(s)
