# %% [markdown]
# ## Callin Switzer
# ## Prep data for batch-generating with Keras
# ## 27 Aug 2018

# %%
# import custom Utils functions
from DeepLearningUtils import *


# define directories
baseDir = os.getcwd()
dataDir = r'D:\MothSimulations\11c-AggressiveManeuver\Qstore\hws_am_con'
figDir = r'D:\Dropbox\mothMachineLearning_dataAndFigs\Figs'
dataOutput = r'D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput'
if not os.path.exists(dataOutput):
    os.mkdir(dataOutput)
    
    
# open file explorer
# aa = r'explorer /select,"'
# subprocess.Popen(str(aa + figDir + '\"'))
# subprocess.Popen(str(aa + dataDir + '\"'))
# Out:
# C:\Users\calli\Anaconda3\envs\deeplearning\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# TensorFlow successfully installed.
# The installed version of TensorFlow includes GPU support.
# 3.6.4 |Anaconda custom (64-bit)| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)]
#
# last run on 2018-08-27 14:47:22.995128

# %%
dataDir2 = r"D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput"
dataFiles = listdir_fullpath(dataDir2)
dataFiles
# Out:
# ['D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_10_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_11_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_12_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_13_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_14_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_15_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_16_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_17_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_18_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_19_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_1_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_20_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_21_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_22_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_23_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_24_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_25_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_26_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_27_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_28_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_29_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_2_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_30_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_31_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_32_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_33_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_34_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_35_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_36_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_3_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_4_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_5_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_6_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_7_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_8_hws_am_con.hdf5',
#  'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_9_hws_am_con.hdf5']

# %%
# define train and validation dataset
np.random.seed(36513654)

partition = {"train": np.random.choice(dataFiles, size = int(0.8*len(dataFiles)), replace = False).tolist()}
partition["validation"] = np.setdiff1d(dataFiles, partition["train"]).tolist()
partition
# Out:
# {'train': ['D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_24_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_26_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_14_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_18_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_27_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_8_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_25_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_2_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_32_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_10_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_35_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_36_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_30_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_34_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_4_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_7_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_29_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_19_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_16_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_23_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_12_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_9_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_13_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_21_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_33_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_5_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_15_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_11_hws_am_con.hdf5'],
#  'validation': ['D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_17_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_1_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_20_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_22_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_28_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_31_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_3_hws_am_con.hdf5',
#   'D:\\Dropbox\\mothMachineLearning_dataAndFigs\\DataOutput\\Qstore_6_hws_am_con.hdf5']}

# %%
dfList = []

for dataFile in dataFiles:
    bf2 = pd.read_hdf(dataFile, "data")
    bf2[['simNum', 'timestep']] = bf2[['simNum', 'timestep']].astype(int)
    bf2['count'] = bf2.groupby(["simNum", "timestep"]).cumcount()
    sdf = bf2.loc[(bf2["count"] == 0) | (bf2["count"] == 99), :]
    ss = sdf.pivot_table(index=['simNum', 'timestep'], columns = "count",aggfunc='first')
    ss.columns = [f'{i}_{j}' if j != '' else f'{i}' for i,j in ss.columns]
    ss.reset_index(inplace=True) 
    dfList.append(ss)
    print(dataFile)
# Out:
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_10_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_11_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_12_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_13_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_14_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_15_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_16_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_17_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_18_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_19_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_1_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_20_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_21_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_22_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_23_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_24_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_25_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_26_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_27_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_28_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_29_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_2_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_30_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_31_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_32_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_33_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_34_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_35_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_36_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_3_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_4_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_5_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_6_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_7_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_8_hws_am_con.hdf5
# D:\Dropbox\mothMachineLearning_dataAndFigs\DataOutput\Qstore_9_hws_am_con.hdf5

# %%
trainDF = pd.concat(dfList)

# %%
trainDF = trainDF.drop(columns=['F_99', 'alpha_99', 
                               'tau_99'])
trainDF=trainDF.rename(columns = {'F_0':'F', 
                                 "alpha_0": "alpha", 
                                 "tau_0": "tau"})

# %%
trainDF.reset_index(inplace = True, drop = True)
print(trainDF.shape)
trainDF.head()
# Out:
# (9000000, 21)
#    simNum  timestep             F     alpha     phi_0    phi_99  phi_dot_0  \
# 0       0         0  38304.433962  5.340270  3.926991  3.869604   0.000000
# 1       0         1  34264.536249  2.465501  3.948428  4.019544   2.009397
# 2       0         2  12045.791872  4.573819  3.966608  3.933017  -0.124272
# 3       0         3  35562.854879  0.767089  4.000007  4.111777   3.434103
# 4       0         4  20856.636628  2.424378  4.009324  3.995061  -2.309667
#
#    phi_dot_99           tau   theta_0     ...      theta_dot_0  theta_dot_99  \
# 0   -5.674295  10963.268558  0.785398     ...         0.000000     -4.770986
# 1    5.425513  72580.767201  0.768478     ...         0.087406     10.479995
# 2   -2.775517  93435.855346  0.768515     ...        -1.029996      3.897680
# 3    7.246049 -96088.338473  0.773977     ...         2.037211      0.318982
# 4    0.686804 -27142.805375  0.815904     ...        -0.673328     -1.304712
#
#         x_0      x_99     x_dot_0    x_dot_99       y_0       y_99  \
# 0  0.000000  6.853314    0.000100  683.734561  0.000000  -1.298536
# 1 -0.019322 -6.079672   -0.145396 -606.129200  2.520087   6.366770
# 2  0.509507  2.986736   52.490438  193.914740  4.834518   2.470847
# 3 -0.836633 -4.334782 -187.046694 -157.064454  6.838940  17.508792
# 4  0.429770  2.895126  313.730247  -65.350386  8.392823   6.771320
#
#       y_dot_0    y_dot_99
# 0    0.000100 -133.752363
# 1  250.908304  120.273149
# 2  -18.848146 -211.050011
# 3  218.755312  844.589134
# 4  -58.222983 -102.458917
#
# [5 rows x 21 columns]

# %%
trainDF.sort_values(["timestep", "simNum"], ascending = [True, True]).head()
# Out:
#          simNum  timestep             F     alpha     phi_0    phi_99  \
# 0             0         0  38304.433962  5.340270  3.926991  3.869604
# 250000        0         0   6143.354049  5.961418  3.926991  3.916364
# 500000        0         0  39225.428283  2.578644  3.926991  3.965986
# 750000        0         0  19970.007383  3.039763  3.926991  3.937839
# 1000000       0         0  10481.140921  3.949336  3.926991  3.905200
#
#          phi_dot_0  phi_dot_99           tau   theta_0     ...      \
# 0              0.0   -5.674295  10963.268558  0.785398     ...
# 250000         0.0   -0.645207  87574.132880  0.785398     ...
# 500000         0.0    3.896474  -4419.593159  0.785398     ...
# 750000         0.0    0.881673 -63747.079038  0.785398     ...
# 1000000        0.0   -1.850964  82273.215370  0.785398     ...
#
#          theta_dot_0  theta_dot_99  x_0      x_99  x_dot_0    x_dot_99  y_0  \
# 0                0.0     -4.770986  0.0  6.853314   0.0001  683.734561  0.0
# 250000           0.0      5.559808  0.0  1.048256   0.0001  100.376445  0.0
# 500000           0.0      3.493059  0.0 -6.930938   0.0001 -691.619443  0.0
# 750000           0.0     -3.654178  0.0 -2.919590   0.0001 -292.316692  0.0
# 1000000          0.0      4.021020  0.0  0.167448   0.0001   16.533703  0.0
#
#              y_99  y_dot_0    y_dot_99
# 0       -1.298536   0.0001 -133.752363
# 250000   0.278338   0.0001   33.038324
# 500000  -1.807255   0.0001 -184.465021
# 750000  -2.360690   0.0001 -234.655195
# 1000000 -2.151740   0.0001 -211.757325
#
# [5 rows x 21 columns]

# %%
trainDF.columns
# Out:
# Index(['simNum', 'timestep', 'F', 'alpha', 'phi_0', 'phi_99', 'phi_dot_0',
#        'phi_dot_99', 'tau', 'theta_0', 'theta_99', 'theta_dot_0',
#        'theta_dot_99', 'x_0', 'x_99', 'x_dot_0', 'x_dot_99', 'y_0', 'y_99',
#        'y_dot_0', 'y_dot_99'],
#       dtype='object')

# %%
# convert to fx and fy
trainDF["Fx"] = trainDF.F * np.cos(trainDF.alpha)
trainDF["Fy"] = trainDF.F * np.sin(trainDF.alpha)

# %% [markdown]
# # Keras models

# %%
# make dataset
X = trainDF.loc[:, ["x_0", "y_0", "phi_0", "theta_0", 
                    "x_99", "y_99", "phi_99", "theta_99"]]
Y = trainDF.loc[:, ["Fx", "Fy", "tau"] ]

# # # subtract x_0 and y_0 from everything
# X.x_99 = X.x_99 - X.x_0
# X.y_99 = X.y_99 - X.y_0

# X.x_0 = X.y_0 = 0

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.3, random_state = 123)

# %%
from sklearn.preprocessing import StandardScaler  
scalerX = StandardScaler()  
scalerY = StandardScaler()  

# Don't cheat - fit only on training data
scalerX.fit(Xtrain)  
scalerY.fit(Ytrain) 

Xtrain_scaled = scalerX.transform(Xtrain)  
Ytrain_scaled = scalerY.transform(Ytrain)  

# apply same transformation to test data
Xtest_scaled = scalerX.transform(Xtest)
Ytest_scaled = scalerY.transform(Ytest)

# %%
# from sklearn.preprocessing import MinMaxScaler  
# scalerX = MinMaxScaler()  
# scalerY = MinMaxScaler()  

# # Don't cheat - fit only on training data
# scalerX.fit(Xtrain)  
# scalerY.fit(Ytrain) 

# Xtrain_scaled = scalerX.transform(Xtrain)  
# Ytrain_scaled = scalerY.transform(Ytrain)  

# # apply same transformation to test data
# Xtest_scaled = scalerX.transform(Xtest)
# Ytest_scaled = scalerY.transform(Ytest)

# %%
# build Keras model with functional API, instead of Sequential
from keras.layers import Input, Dense
from keras.models import Model

# callcacks
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
inputs = Input(shape=(Xtrain_scaled.shape[1],))

x = Dense(400, activation='tanh')(inputs)
x = Dense(400, activation='tanh')(x)
x = Dense(400, activation='tanh')(x)
x = Dense(16, activation='tanh')(x)
predictions = Dense(Ytrain_scaled.shape[1], activation='linear')(x)

# This creates a model that includes
# the Input layer and three Dense layers
model = Model(inputs=inputs, outputs=predictions)
model.compile(loss="mse", optimizer="adam", metrics = ['mse'])

# %%
earlystop = EarlyStopping(monitor='val_mean_squared_error', patience=50, 
                          verbose=1, mode='auto', min_delta = 0.0001)

history = model.fit(Xtrain_scaled, Ytrain_scaled, validation_split = 0.3, 
                    verbose = 2, batch_size=2**13, epochs = 1000, 
                    callbacks = [earlystop])
# Out:
# Train on 4410000 samples, validate on 1890000 samples
# Epoch 1/1000
#  - 9s - loss: 0.3027 - mean_squared_error: 0.3027 - val_loss: 0.2815 - val_mean_squared_error: 0.2815
# Epoch 2/1000
#  - 6s - loss: 0.2757 - mean_squared_error: 0.2757 - val_loss: 0.2709 - val_mean_squared_error: 0.2709
# Epoch 3/1000
#  - 6s - loss: 0.2628 - mean_squared_error: 0.2628 - val_loss: 0.2546 - val_mean_squared_error: 0.2546
# Epoch 4/1000
#  - 6s - loss: 0.2417 - mean_squared_error: 0.2417 - val_loss: 0.2295 - val_mean_squared_error: 0.2295
# Epoch 5/1000
#  - 6s - loss: 0.2121 - mean_squared_error: 0.2121 - val_loss: 0.1946 - val_mean_squared_error: 0.1946
# Epoch 6/1000
#  - 6s - loss: 0.1734 - mean_squared_error: 0.1734 - val_loss: 0.1518 - val_mean_squared_error: 0.1518
# Epoch 7/1000
#  - 6s - loss: 0.1325 - mean_squared_error: 0.1325 - val_loss: 0.1168 - val_mean_squared_error: 0.1168
# Epoch 8/1000
#  - 6s - loss: 0.0967 - mean_squared_error: 0.0967 - val_loss: 0.0871 - val_mean_squared_error: 0.0871
# Epoch 9/1000
#  - 6s - loss: 0.0702 - mean_squared_error: 0.0702 - val_loss: 0.0620 - val_mean_squared_error: 0.0620
# Epoch 10/1000
#  - 6s - loss: 0.0518 - mean_squared_error: 0.0518 - val_loss: 0.0512 - val_mean_squared_error: 0.0512
# Epoch 11/1000
#  - 6s - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0323 - val_mean_squared_error: 0.0323
# Epoch 12/1000
#  - 6s - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 13/1000
#  - 6s - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 14/1000
#  - 6s - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 15/1000
#  - 6s - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 16/1000
#  - 6s - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0121 - val_mean_squared_error: 0.0121
# Epoch 17/1000
#  - 6s - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 18/1000
#  - 6s - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 19/1000
#  - 6s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 20/1000
#  - 6s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 21/1000
#  - 6s - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 22/1000
#  - 6s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 23/1000
#  - 6s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 24/1000
#  - 6s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 25/1000
#  - 6s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 26/1000
#  - 6s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 27/1000
#  - 6s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 28/1000
#  - 6s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 29/1000
#  - 6s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 30/1000
#  - 6s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 31/1000
#  - 6s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 32/1000
#  - 6s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 33/1000
#  - 6s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 34/1000
#  - 6s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 35/1000
#  - 6s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 36/1000
#  - 6s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 37/1000
#  - 6s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 38/1000
#  - 6s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 39/1000
#  - 6s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 40/1000
#  - 6s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 41/1000
#  - 6s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 42/1000
#  - 6s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 43/1000
#  - 6s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 44/1000
#  - 6s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 45/1000
#  - 6s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 46/1000
#  - 6s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 47/1000
#  - 6s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 48/1000
#  - 6s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 49/1000
#  - 6s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 50/1000
#  - 6s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 51/1000
#  - 6s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 52/1000
#  - 6s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 53/1000
#  - 6s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 54/1000
#  - 6s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 55/1000
#  - 6s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 56/1000
#  - 6s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 57/1000
#  - 6s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 58/1000
#  - 6s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 59/1000
#  - 6s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 60/1000
#  - 6s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 61/1000
#  - 6s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 62/1000
#  - 6s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 63/1000
#  - 6s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 64/1000
#  - 6s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 65/1000
#  - 6s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 66/1000
#  - 6s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 67/1000
#  - 6s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 68/1000
#  - 6s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 69/1000
#  - 6s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 70/1000
#  - 6s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 71/1000
#  - 6s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
# Epoch 72/1000
#  - 6s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 73/1000
#  - 6s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 74/1000
#  - 6s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 75/1000
#  - 6s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 76/1000
#  - 6s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 77/1000
#  - 6s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 78/1000
#  - 6s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 79/1000
#  - 6s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 80/1000
#  - 6s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 81/1000
#  - 6s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 82/1000
#  - 6s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 83/1000
#  - 6s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 84/1000
#  - 6s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 85/1000
#  - 6s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 86/1000
#  - 6s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 87/1000
#  - 6s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 88/1000
#  - 6s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 89/1000
#  - 6s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 90/1000
#  - 6s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 91/1000
#  - 6s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 92/1000
#  - 6s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 93/1000
#  - 6s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 94/1000
#  - 6s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 95/1000
#  - 6s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 96/1000
#  - 6s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 97/1000
#  - 6s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 98/1000
#  - 6s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 99/1000
#  - 6s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 100/1000
#  - 6s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 101/1000
#  - 6s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 102/1000
#  - 6s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 103/1000
#  - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 104/1000
#  - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 105/1000
#  - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 9.4052e-04 - val_mean_squared_error: 9.4052e-04
# Epoch 106/1000
#  - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 107/1000
#  - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 108/1000
#  - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 109/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 110/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 111/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 112/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 113/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 114/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 115/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 116/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 117/1000
#  - 6s - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 118/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 119/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 120/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 121/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 122/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 123/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 124/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 125/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 126/1000
#  - 6s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 9.5449e-04 - val_mean_squared_error: 9.5449e-04
# Epoch 127/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 128/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 129/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 130/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 131/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 9.4679e-04 - val_mean_squared_error: 9.4679e-04
# Epoch 132/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 133/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 134/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 8.4127e-04 - val_mean_squared_error: 8.4127e-04
# Epoch 135/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 136/1000
#  - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 137/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 138/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 139/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 140/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 7.6953e-04 - val_mean_squared_error: 7.6953e-04
# Epoch 141/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 142/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 143/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 144/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 145/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 146/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 147/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 148/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 9.4367e-04 - val_mean_squared_error: 9.4367e-04
# Epoch 149/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 150/1000
#  - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 9.6281e-04 - val_mean_squared_error: 9.6281e-04
# Epoch 151/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 152/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 153/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 154/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 155/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 156/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 157/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 158/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 159/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.6809e-04 - val_mean_squared_error: 7.6809e-04
# Epoch 160/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 161/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 162/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 8.2955e-04 - val_mean_squared_error: 8.2955e-04
# Epoch 163/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 164/1000
#  - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 165/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 166/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 167/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 168/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 169/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 170/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 171/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 8.2537e-04 - val_mean_squared_error: 8.2537e-04
# Epoch 172/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 173/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 174/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 175/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2333e-04 - val_mean_squared_error: 7.2333e-04
# Epoch 176/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 177/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 178/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 179/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 180/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.3729e-04 - val_mean_squared_error: 6.3729e-04
# Epoch 181/1000
#  - 6s - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 182/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 183/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 184/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.9884e-04 - val_mean_squared_error: 9.9884e-04
# Epoch 185/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 186/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.8603e-04 - val_mean_squared_error: 5.8603e-04
# Epoch 187/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.7535e-04 - val_mean_squared_error: 6.7535e-04
# Epoch 188/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.5708e-04 - val_mean_squared_error: 9.5708e-04
# Epoch 189/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 7.2285e-04 - val_mean_squared_error: 7.2285e-04
# Epoch 190/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 191/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.8937e-04 - val_mean_squared_error: 9.8937e-04
# Epoch 192/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 6.9010e-04 - val_mean_squared_error: 6.9010e-04
# Epoch 193/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 7.7321e-04 - val_mean_squared_error: 7.7321e-04
# Epoch 194/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 195/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 196/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 8.7746e-04 - val_mean_squared_error: 8.7746e-04
# Epoch 197/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 8.2613e-04 - val_mean_squared_error: 8.2613e-04
# Epoch 198/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 199/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 200/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 201/1000
#  - 6s - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 8.7141e-04 - val_mean_squared_error: 8.7141e-04
# Epoch 202/1000
#  - 6s - loss: 9.9329e-04 - mean_squared_error: 9.9329e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 203/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 204/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.9648e-04 - val_mean_squared_error: 9.9648e-04
# Epoch 205/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.5541e-04 - val_mean_squared_error: 5.5541e-04
# Epoch 206/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.0907e-04 - val_mean_squared_error: 6.0907e-04
# Epoch 207/1000
#  - 6s - loss: 9.7166e-04 - mean_squared_error: 9.7166e-04 - val_loss: 9.8694e-04 - val_mean_squared_error: 9.8694e-04
# Epoch 208/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 7.6815e-04 - val_mean_squared_error: 7.6815e-04
# Epoch 209/1000
#  - 6s - loss: 9.9381e-04 - mean_squared_error: 9.9381e-04 - val_loss: 8.7050e-04 - val_mean_squared_error: 8.7050e-04
# Epoch 210/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 211/1000
#  - 6s - loss: 9.8465e-04 - mean_squared_error: 9.8465e-04 - val_loss: 4.9753e-04 - val_mean_squared_error: 4.9753e-04
# Epoch 212/1000
#  - 6s - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.4798e-04 - val_mean_squared_error: 5.4798e-04
# Epoch 213/1000
#  - 6s - loss: 9.2705e-04 - mean_squared_error: 9.2705e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 214/1000
#  - 6s - loss: 9.8152e-04 - mean_squared_error: 9.8152e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 215/1000
#  - 6s - loss: 9.8723e-04 - mean_squared_error: 9.8723e-04 - val_loss: 8.6951e-04 - val_mean_squared_error: 8.6951e-04
# Epoch 216/1000
#  - 6s - loss: 9.7243e-04 - mean_squared_error: 9.7243e-04 - val_loss: 8.3244e-04 - val_mean_squared_error: 8.3244e-04
# Epoch 217/1000
#  - 6s - loss: 9.4875e-04 - mean_squared_error: 9.4875e-04 - val_loss: 8.9410e-04 - val_mean_squared_error: 8.9410e-04
# Epoch 218/1000
#  - 6s - loss: 9.6123e-04 - mean_squared_error: 9.6123e-04 - val_loss: 9.6661e-04 - val_mean_squared_error: 9.6661e-04
# Epoch 219/1000
#  - 6s - loss: 9.7310e-04 - mean_squared_error: 9.7310e-04 - val_loss: 7.3947e-04 - val_mean_squared_error: 7.3947e-04
# Epoch 220/1000
#  - 6s - loss: 9.5141e-04 - mean_squared_error: 9.5141e-04 - val_loss: 7.3623e-04 - val_mean_squared_error: 7.3623e-04
# Epoch 221/1000
#  - 6s - loss: 9.4385e-04 - mean_squared_error: 9.4385e-04 - val_loss: 7.0041e-04 - val_mean_squared_error: 7.0041e-04
# Epoch 222/1000
#  - 6s - loss: 9.2691e-04 - mean_squared_error: 9.2691e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 223/1000
#  - 6s - loss: 9.6417e-04 - mean_squared_error: 9.6417e-04 - val_loss: 8.4144e-04 - val_mean_squared_error: 8.4144e-04
# Epoch 224/1000
#  - 6s - loss: 9.1642e-04 - mean_squared_error: 9.1642e-04 - val_loss: 6.9098e-04 - val_mean_squared_error: 6.9098e-04
# Epoch 225/1000
#  - 6s - loss: 9.5456e-04 - mean_squared_error: 9.5456e-04 - val_loss: 5.5632e-04 - val_mean_squared_error: 5.5632e-04
# Epoch 226/1000
#  - 6s - loss: 9.4830e-04 - mean_squared_error: 9.4830e-04 - val_loss: 4.8736e-04 - val_mean_squared_error: 4.8736e-04
# Epoch 227/1000
#  - 6s - loss: 8.9082e-04 - mean_squared_error: 8.9082e-04 - val_loss: 7.3945e-04 - val_mean_squared_error: 7.3945e-04
# Epoch 228/1000
#  - 6s - loss: 9.3499e-04 - mean_squared_error: 9.3499e-04 - val_loss: 9.3091e-04 - val_mean_squared_error: 9.3091e-04
# Epoch 229/1000
#  - 6s - loss: 9.3379e-04 - mean_squared_error: 9.3379e-04 - val_loss: 8.4384e-04 - val_mean_squared_error: 8.4384e-04
# Epoch 230/1000
#  - 6s - loss: 9.1217e-04 - mean_squared_error: 9.1217e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 231/1000
#  - 6s - loss: 9.3835e-04 - mean_squared_error: 9.3835e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 232/1000
#  - 6s - loss: 8.9230e-04 - mean_squared_error: 8.9230e-04 - val_loss: 6.2428e-04 - val_mean_squared_error: 6.2428e-04
# Epoch 233/1000
#  - 6s - loss: 9.2161e-04 - mean_squared_error: 9.2161e-04 - val_loss: 7.0693e-04 - val_mean_squared_error: 7.0693e-04
# Epoch 234/1000
#  - 6s - loss: 9.0095e-04 - mean_squared_error: 9.0095e-04 - val_loss: 9.3522e-04 - val_mean_squared_error: 9.3522e-04
# Epoch 235/1000
#  - 6s - loss: 8.9638e-04 - mean_squared_error: 8.9638e-04 - val_loss: 6.3054e-04 - val_mean_squared_error: 6.3054e-04
# Epoch 236/1000
#  - 6s - loss: 8.9698e-04 - mean_squared_error: 8.9698e-04 - val_loss: 8.0044e-04 - val_mean_squared_error: 8.0044e-04
# Epoch 237/1000
#  - 6s - loss: 9.0353e-04 - mean_squared_error: 9.0353e-04 - val_loss: 7.6730e-04 - val_mean_squared_error: 7.6730e-04
# Epoch 238/1000
#  - 6s - loss: 9.1347e-04 - mean_squared_error: 9.1347e-04 - val_loss: 9.3901e-04 - val_mean_squared_error: 9.3901e-04
# Epoch 239/1000
#  - 6s - loss: 8.7165e-04 - mean_squared_error: 8.7165e-04 - val_loss: 6.3140e-04 - val_mean_squared_error: 6.3140e-04
# Epoch 240/1000
#  - 6s - loss: 8.8279e-04 - mean_squared_error: 8.8279e-04 - val_loss: 7.6665e-04 - val_mean_squared_error: 7.6665e-04
# Epoch 241/1000
#  - 6s - loss: 8.9412e-04 - mean_squared_error: 8.9412e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 242/1000
#  - 6s - loss: 8.8975e-04 - mean_squared_error: 8.8975e-04 - val_loss: 5.8948e-04 - val_mean_squared_error: 5.8948e-04
# Epoch 243/1000
#  - 6s - loss: 8.6410e-04 - mean_squared_error: 8.6410e-04 - val_loss: 7.9189e-04 - val_mean_squared_error: 7.9189e-04
# Epoch 244/1000
#  - 6s - loss: 8.7710e-04 - mean_squared_error: 8.7710e-04 - val_loss: 5.2834e-04 - val_mean_squared_error: 5.2834e-04
# Epoch 245/1000
#  - 6s - loss: 8.8264e-04 - mean_squared_error: 8.8264e-04 - val_loss: 7.7641e-04 - val_mean_squared_error: 7.7641e-04
# Epoch 246/1000
#  - 6s - loss: 8.7918e-04 - mean_squared_error: 8.7918e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 247/1000
#  - 6s - loss: 8.6240e-04 - mean_squared_error: 8.6240e-04 - val_loss: 6.0138e-04 - val_mean_squared_error: 6.0138e-04
# Epoch 248/1000
#  - 6s - loss: 8.5742e-04 - mean_squared_error: 8.5742e-04 - val_loss: 6.7214e-04 - val_mean_squared_error: 6.7214e-04
# Epoch 249/1000
#  - 6s - loss: 8.4358e-04 - mean_squared_error: 8.4358e-04 - val_loss: 6.2775e-04 - val_mean_squared_error: 6.2775e-04
# Epoch 250/1000
#  - 6s - loss: 8.6349e-04 - mean_squared_error: 8.6349e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 251/1000
#  - 6s - loss: 8.6879e-04 - mean_squared_error: 8.6879e-04 - val_loss: 8.4442e-04 - val_mean_squared_error: 8.4442e-04
# Epoch 252/1000
#  - 6s - loss: 8.4809e-04 - mean_squared_error: 8.4809e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 253/1000
#  - 6s - loss: 8.4197e-04 - mean_squared_error: 8.4197e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 254/1000
#  - 6s - loss: 8.4473e-04 - mean_squared_error: 8.4473e-04 - val_loss: 4.6048e-04 - val_mean_squared_error: 4.6048e-04
# Epoch 255/1000
#  - 6s - loss: 8.4523e-04 - mean_squared_error: 8.4523e-04 - val_loss: 4.7838e-04 - val_mean_squared_error: 4.7838e-04
# Epoch 256/1000
#  - 6s - loss: 8.4681e-04 - mean_squared_error: 8.4681e-04 - val_loss: 6.2050e-04 - val_mean_squared_error: 6.2050e-04
# Epoch 257/1000
#  - 6s - loss: 8.2572e-04 - mean_squared_error: 8.2572e-04 - val_loss: 3.6578e-04 - val_mean_squared_error: 3.6578e-04
# Epoch 258/1000
#  - 6s - loss: 8.5090e-04 - mean_squared_error: 8.5090e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 259/1000
#  - 6s - loss: 8.2405e-04 - mean_squared_error: 8.2405e-04 - val_loss: 5.8770e-04 - val_mean_squared_error: 5.8770e-04
# Epoch 260/1000
#  - 6s - loss: 8.3019e-04 - mean_squared_error: 8.3019e-04 - val_loss: 9.6353e-04 - val_mean_squared_error: 9.6353e-04
# Epoch 261/1000
#  - 6s - loss: 8.2503e-04 - mean_squared_error: 8.2503e-04 - val_loss: 4.5386e-04 - val_mean_squared_error: 4.5386e-04
# Epoch 262/1000
#  - 6s - loss: 8.2927e-04 - mean_squared_error: 8.2927e-04 - val_loss: 5.5901e-04 - val_mean_squared_error: 5.5901e-04
# Epoch 263/1000
#  - 6s - loss: 8.1528e-04 - mean_squared_error: 8.1528e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 264/1000
#  - 6s - loss: 8.2358e-04 - mean_squared_error: 8.2358e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 265/1000
#  - 6s - loss: 8.4043e-04 - mean_squared_error: 8.4043e-04 - val_loss: 5.9475e-04 - val_mean_squared_error: 5.9475e-04
# Epoch 266/1000
#  - 6s - loss: 8.0026e-04 - mean_squared_error: 8.0026e-04 - val_loss: 4.1623e-04 - val_mean_squared_error: 4.1623e-04
# Epoch 267/1000
#  - 6s - loss: 8.1044e-04 - mean_squared_error: 8.1044e-04 - val_loss: 7.3996e-04 - val_mean_squared_error: 7.3996e-04
# Epoch 268/1000
#  - 6s - loss: 8.1877e-04 - mean_squared_error: 8.1877e-04 - val_loss: 8.5281e-04 - val_mean_squared_error: 8.5281e-04
# Epoch 269/1000
#  - 6s - loss: 7.8731e-04 - mean_squared_error: 7.8731e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 270/1000
#  - 6s - loss: 8.1236e-04 - mean_squared_error: 8.1236e-04 - val_loss: 5.5710e-04 - val_mean_squared_error: 5.5710e-04
# Epoch 271/1000
#  - 6s - loss: 8.1344e-04 - mean_squared_error: 8.1344e-04 - val_loss: 6.6800e-04 - val_mean_squared_error: 6.6800e-04
# Epoch 272/1000
#  - 6s - loss: 8.0014e-04 - mean_squared_error: 8.0014e-04 - val_loss: 6.8248e-04 - val_mean_squared_error: 6.8248e-04
# Epoch 273/1000
#  - 6s - loss: 7.9148e-04 - mean_squared_error: 7.9148e-04 - val_loss: 5.0099e-04 - val_mean_squared_error: 5.0099e-04
# Epoch 274/1000
#  - 6s - loss: 7.8672e-04 - mean_squared_error: 7.8672e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 275/1000
#  - 6s - loss: 7.8179e-04 - mean_squared_error: 7.8179e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 276/1000
#  - 6s - loss: 7.8294e-04 - mean_squared_error: 7.8294e-04 - val_loss: 5.8408e-04 - val_mean_squared_error: 5.8408e-04
# Epoch 277/1000
#  - 6s - loss: 7.9800e-04 - mean_squared_error: 7.9800e-04 - val_loss: 9.6703e-04 - val_mean_squared_error: 9.6703e-04
# Epoch 278/1000
#  - 6s - loss: 7.8533e-04 - mean_squared_error: 7.8533e-04 - val_loss: 5.2439e-04 - val_mean_squared_error: 5.2439e-04
# Epoch 279/1000
#  - 6s - loss: 7.6540e-04 - mean_squared_error: 7.6540e-04 - val_loss: 7.7138e-04 - val_mean_squared_error: 7.7138e-04
# Epoch 280/1000
#  - 6s - loss: 7.6294e-04 - mean_squared_error: 7.6294e-04 - val_loss: 5.4937e-04 - val_mean_squared_error: 5.4937e-04
# Epoch 281/1000
#  - 6s - loss: 7.7561e-04 - mean_squared_error: 7.7561e-04 - val_loss: 8.0387e-04 - val_mean_squared_error: 8.0387e-04
# Epoch 282/1000
#  - 6s - loss: 7.7244e-04 - mean_squared_error: 7.7244e-04 - val_loss: 5.3930e-04 - val_mean_squared_error: 5.3930e-04
# Epoch 283/1000
#  - 6s - loss: 7.6062e-04 - mean_squared_error: 7.6062e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 284/1000
#  - 6s - loss: 7.6356e-04 - mean_squared_error: 7.6356e-04 - val_loss: 6.0934e-04 - val_mean_squared_error: 6.0934e-04
# Epoch 285/1000
#  - 6s - loss: 7.4658e-04 - mean_squared_error: 7.4658e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 286/1000
#  - 6s - loss: 7.4106e-04 - mean_squared_error: 7.4106e-04 - val_loss: 5.9914e-04 - val_mean_squared_error: 5.9914e-04
# Epoch 287/1000
#  - 6s - loss: 7.6032e-04 - mean_squared_error: 7.6032e-04 - val_loss: 5.6169e-04 - val_mean_squared_error: 5.6169e-04
# Epoch 288/1000
#  - 6s - loss: 7.4814e-04 - mean_squared_error: 7.4814e-04 - val_loss: 4.8700e-04 - val_mean_squared_error: 4.8700e-04
# Epoch 289/1000
#  - 6s - loss: 7.7295e-04 - mean_squared_error: 7.7295e-04 - val_loss: 3.5899e-04 - val_mean_squared_error: 3.5899e-04
# Epoch 290/1000
#  - 6s - loss: 7.5245e-04 - mean_squared_error: 7.5245e-04 - val_loss: 6.5140e-04 - val_mean_squared_error: 6.5140e-04
# Epoch 291/1000
#  - 6s - loss: 7.1617e-04 - mean_squared_error: 7.1617e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 292/1000
#  - 6s - loss: 7.5167e-04 - mean_squared_error: 7.5167e-04 - val_loss: 4.5636e-04 - val_mean_squared_error: 4.5636e-04
# Epoch 293/1000
#  - 6s - loss: 7.1993e-04 - mean_squared_error: 7.1993e-04 - val_loss: 7.7104e-04 - val_mean_squared_error: 7.7104e-04
# Epoch 294/1000
#  - 6s - loss: 7.4459e-04 - mean_squared_error: 7.4459e-04 - val_loss: 6.4613e-04 - val_mean_squared_error: 6.4613e-04
# Epoch 295/1000
#  - 6s - loss: 7.3516e-04 - mean_squared_error: 7.3516e-04 - val_loss: 4.2627e-04 - val_mean_squared_error: 4.2627e-04
# Epoch 296/1000
#  - 6s - loss: 7.1398e-04 - mean_squared_error: 7.1398e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 297/1000
#  - 6s - loss: 7.3326e-04 - mean_squared_error: 7.3326e-04 - val_loss: 4.5212e-04 - val_mean_squared_error: 4.5212e-04
# Epoch 298/1000
#  - 6s - loss: 7.5073e-04 - mean_squared_error: 7.5073e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 299/1000
#  - 6s - loss: 7.0957e-04 - mean_squared_error: 7.0957e-04 - val_loss: 8.9403e-04 - val_mean_squared_error: 8.9403e-04
# Epoch 300/1000
#  - 6s - loss: 7.1487e-04 - mean_squared_error: 7.1487e-04 - val_loss: 8.6945e-04 - val_mean_squared_error: 8.6945e-04
# Epoch 301/1000
#  - 6s - loss: 7.2388e-04 - mean_squared_error: 7.2388e-04 - val_loss: 5.3813e-04 - val_mean_squared_error: 5.3813e-04
# Epoch 302/1000
#  - 6s - loss: 7.2532e-04 - mean_squared_error: 7.2532e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 303/1000
#  - 6s - loss: 7.1387e-04 - mean_squared_error: 7.1387e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 304/1000
#  - 6s - loss: 7.1670e-04 - mean_squared_error: 7.1670e-04 - val_loss: 6.6803e-04 - val_mean_squared_error: 6.6803e-04
# Epoch 305/1000
#  - 6s - loss: 7.0594e-04 - mean_squared_error: 7.0594e-04 - val_loss: 5.6532e-04 - val_mean_squared_error: 5.6532e-04
# Epoch 306/1000
#  - 6s - loss: 6.9598e-04 - mean_squared_error: 6.9598e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 307/1000
#  - 6s - loss: 7.2644e-04 - mean_squared_error: 7.2644e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 00307: early stopping

# %%
def plot_model_history(model_history, saveFig = False):
    fig, axs = plt.subplots(1,1,figsize=(10,5))
    # summarize history for accuracy
    axs.plot(range(1,len(model_history.history['mean_squared_error'])+1),
             model_history.history['mean_squared_error'])
    axs.plot(range(1,len(model_history.history['val_mean_squared_error'])+1),
             model_history.history['val_mean_squared_error'])
    axs.set_title('Model MSE')
    axs.set_ylabel('mean_squared_error')
    axs.set_xlabel('Epoch')
    axs.set_xticks(np.arange(1,len(model_history.history['val_mean_squared_error'])+1),
                   len(model_history.history['val_mean_squared_error'])/10)
    axs.legend(['train', 'val'], loc='best')
    if saveFig:
        fig.savefig(os.path.join(figDir, "ModelTraining.png"), dpi = 120, bbox_inches='tight')
    plt.show()

# %%
plot_model_history(history, saveFig = True)

# %%
nnpreds = model.predict(Xtest_scaled)

# %%
plt.close("all")
fig, axs = plt.subplots(1,3, figsize=(15, 5), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.3)
fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel()

nms = ["Fx", "Fy", "tau"]

for ii in range(3):
    # read in image
    
    try:
        axs[ii].scatter(y = Ytest_scaled[:,ii],x = nnpreds[:,ii], s = 1, alpha = 0.1 )
        axs[ii].set_xlabel("Predicted Value (scaled)")
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value\n(scaled)")
        axs[ii].set_title(nms[ii])
        axs[ii].plot(Ytest_scaled[:,ii], Ytest_scaled[:,ii], 'b')
    except:
        pass

    
fig.savefig(os.path.join(figDir, "NNPreds_newData_control_bigbatch_FxFy.png"), dpi = 120, bbox_inches='tight')

# %%
# refref: idea - predict whole paths, rather than just the endpoint

# %%
plt.close("all")
fig, axs = plt.subplots(1,3, figsize=(15, 5), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = 0.1, wspace=0.3)
fig.suptitle('Predicted vs. acutal ', fontsize=14, fontweight='bold')

axs = axs.ravel()

nms = ["Fx", "Fy", "tau"]


# replace lightest colors with white
import matplotlib.colors

cmap = plt.cm.magma_r
cmaplist = np.array([cmap(i) for i in range(cmap.N)])
#cmaplist[0:2] = np.repeat((0.0,0.0,0.0,0.0), 2).reshape(-1,4)
cmaplist[:,0:3] = np.divide(cmaplist[:, 0:3], 1.1)
#cmaplist[:,0:3] = np.transpose(np.vstack([np.linspace(1, 0, 256), np.linspace(1, 0, 256), np.linspace(1, 0, 256)]))
cmaplist[0] = (1,1,1,0.5)
cmap = matplotlib.colors.LinearSegmentedColormap.from_list('mcm',cmaplist, cmap.N)

for ii in range(3):
    # read in image
    
    try:
        axs[ii].hexbin(y = Ytest_scaled[:,ii],x = nnpreds[:,ii], gridsize = 150, cmap = cmap)
        axs[ii].set_xlabel("Predicted Value (scaled)")
        if(ii == 0):
            axs[ii].set_ylabel("Actual Value\n(scaled)")
        axs[ii].set_title(nms[ii])
        axs[ii].plot(Ytest_scaled[:,ii], Ytest_scaled[:,ii], 'grey', linewidth = 1, linestyle  = "--")
    except:
        pass

fig.savefig(os.path.join(figDir, "NNPreds_newData_control_bigbatch_FxFy_hexbin.png"), dpi = 120, bbox_inches='tight')

# %%
bf2[['simNum', 'timestep']] = bf2[['simNum', 'timestep']].astype(int)

bf2['count'] = bf2.groupby(["simNum", "timestep"]).cumcount()

bf2.head()

bf2.tail()

sdf = bf2.loc[(bf2["count"] == 0) | (bf2["count"] == 99), :]
sdf.head()

ss = sdf.pivot_table(index='simNum', columns = "count",aggfunc='first')
ss.columns = [f'{i}_{j}' if j != '' else f'{i}' for i,j in ss.columns]
ss["simNum"] = ss.index
ss.index.name = None
ss.head()

np.array(ss).shape

np.vstack([np.array(ss), np.array(ss)]).shape
