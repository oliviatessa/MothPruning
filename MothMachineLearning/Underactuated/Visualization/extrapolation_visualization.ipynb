# %%
import os 
import pickle 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
lossDir = '/home/olivia/mothPruning/mothMachineLearning_dataAndFigs/DataOutput/Experiments/2022_04_13__08_11_26/'

trainLosses = pickle.load(open(os.path.join(lossDir, 'allPruneLosses_minmax_Adam5_1.pkl'), 'rb'))
testLosses = pickle.load(open(os.path.join(lossDir, 'alltestPruneLosses_minmax_Adam5_1.pkl'), 'rb'))
valLosses = pickle.load(open(os.path.join(lossDir, 'allvalPruneLosses_minmax_Adam5_1.pkl'), 'rb'))

trainLosses09 = pickle.load(open(os.path.join(lossDir, 'allPruneLosses_minmax_Adam5_0_9.pkl'), 'rb'))
testLosses09 = pickle.load(open(os.path.join(lossDir, 'alltestPruneLosses_minmax_Adam5_0_9.pkl'), 'rb'))
valLosses09 = pickle.load(open(os.path.join(lossDir, 'allvalPruneLosses_minmax_Adam5_0_9.pkl'), 'rb'))

trainLosses08 = pickle.load(open(os.path.join(lossDir, 'allPruneLosses_minmax_Adam5_0_8.pkl'), 'rb'))
testLosses08 = pickle.load(open(os.path.join(lossDir, 'alltestPruneLosses_minmax_Adam5_0_8.pkl'), 'rb'))
valLosses08 = pickle.load(open(os.path.join(lossDir, 'allvalPruneLosses_minmax_Adam5_0_8.pkl'), 'rb'))

trainLosses07 = pickle.load(open(os.path.join(lossDir, 'allPruneLosses_minmax_Adam5_0_7.pkl'), 'rb'))
testLosses07 = pickle.load(open(os.path.join(lossDir, 'alltestPruneLosses_minmax_Adam5_0_7.pkl'), 'rb'))
valLosses07 = pickle.load(open(os.path.join(lossDir, 'allvalPruneLosses_minmax_Adam5_0_7.pkl'), 'rb'))

trainLosses06 = pickle.load(open(os.path.join(lossDir, 'allPruneLosses_minmax_Adam5_0_6.pkl'), 'rb'))
testLosses06 = pickle.load(open(os.path.join(lossDir, 'alltestPruneLosses_minmax_Adam5_0_6.pkl'), 'rb'))
valLosses06 = pickle.load(open(os.path.join(lossDir, 'allvalPruneLosses_minmax_Adam5_0_6.pkl'), 'rb'))

trainLosses05 = pickle.load(open(os.path.join(lossDir, 'allPruneLosses_minmax_Adam5_0_5.pkl'), 'rb'))
testLosses05 = pickle.load(open(os.path.join(lossDir, 'alltestPruneLosses_minmax_Adam5_0_5.pkl'), 'rb'))
valLosses05= pickle.load(open(os.path.join(lossDir, 'allvalPruneLosses_minmax_Adam5_0_5.pkl'), 'rb'))





lossesDF = pd.DataFrame(np.transpose(trainLosses), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
testlossesDF = pd.DataFrame(np.transpose(testLosses), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
vallossesDF = pd.DataFrame(np.transpose(valLosses), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])

losses09DF = pd.DataFrame(np.transpose(trainLosses09), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
testlosses09DF = pd.DataFrame(np.transpose(testLosses09), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
vallosses09DF = pd.DataFrame(np.transpose(valLosses09), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])

losses08DF = pd.DataFrame(np.transpose(trainLosses08), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
testlosses08DF = pd.DataFrame(np.transpose(testLosses08), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
vallosses08DF = pd.DataFrame(np.transpose(valLosses08), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])

losses07DF = pd.DataFrame(np.transpose(trainLosses07), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
testlosses07DF = pd.DataFrame(np.transpose(testLosses07), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
vallosses07DF = pd.DataFrame(np.transpose(valLosses07), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])

losses06DF = pd.DataFrame(np.transpose(trainLosses06), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
testlosses06DF = pd.DataFrame(np.transpose(testLosses06), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
vallosses06DF = pd.DataFrame(np.transpose(valLosses06), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])

losses05DF = pd.DataFrame(np.transpose(trainLosses05), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
testlosses05DF = pd.DataFrame(np.transpose(testLosses05), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
vallosses05DF = pd.DataFrame(np.transpose(valLosses05), columns=['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])

# %%
df_1 = pd.DataFrame(testlossesDF['0%'])
df_09 = pd.DataFrame(testlosses09DF['0%'])
df_08 = pd.DataFrame(testlosses08DF['0%'])
df_07 = pd.DataFrame(testlosses07DF['0%'])
df_06 = pd.DataFrame(testlosses06DF['0%'])
df_05 = pd.DataFrame(testlosses05DF['0%'])

df_1.insert(0, 'x', np.ones((100)))
df_09.insert(0, 'x', 0.9*np.ones((100)))
df_08.insert(0, 'x', 0.8*np.ones((100)))
df_07.insert(0, 'x', 0.7*np.ones((100)))
df_06.insert(0, 'x', 0.6*np.ones((100)))
df_05.insert(0, 'x', 0.5*np.ones((100)))

df0 = pd.concat([df_1, df_09, df_08, df_07, df_06, df_05])

# %%
prune_list = ['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ]
df0 = pd.DataFrame()
df15 = pd.DataFrame()
df25 = pd.DataFrame()
df35 = pd.DataFrame()
df45 = pd.DataFrame()
df55 = pd.DataFrame()
df65 = pd.DataFrame()
df75 = pd.DataFrame()
df85 = pd.DataFrame()
df90 = pd.DataFrame()
df91 = pd.DataFrame()
df92 = pd.DataFrame()
df93 = pd.DataFrame()
df94 = pd.DataFrame()
df95 = pd.DataFrame()
df96 = pd.DataFrame()
df97 = pd.DataFrame()
df98 = pd.DataFrame()


df_list = [df0, df15, df25, df35, df45, df55, df65, df75, df85, df90, df91, df92, df93, df94, df95, df96, df97, df98]

for p in range(len(prune_list)):
    prune = prune_list[p]
    df_1 = pd.DataFrame(testlossesDF[prune])
    df_09 = pd.DataFrame(testlosses09DF[prune])
    df_08 = pd.DataFrame(testlosses08DF[prune])
    df_07 = pd.DataFrame(testlosses07DF[prune])
    df_06 = pd.DataFrame(testlosses06DF[prune])
    df_05 = pd.DataFrame(testlosses05DF[prune])

    df_1.insert(0, 'x', np.ones((100)))
    df_09.insert(0, 'x', 0.9*np.ones((100)))
    df_08.insert(0, 'x', 0.8*np.ones((100)))
    df_07.insert(0, 'x', 0.7*np.ones((100)))
    df_06.insert(0, 'x', 0.6*np.ones((100)))
    df_05.insert(0, 'x', 0.5*np.ones((100)))

    df_list[p] = pd.concat([df_1, df_09, df_08, df_07, df_06, df_05])

# %%
df_list[1]
# Out:
#       x       15%
# 0   1.0  0.000305
# 1   1.0  0.000498
# 2   1.0  0.000350
# 3   1.0  0.000500
# 4   1.0  0.000380
# ..  ...       ...
# 95  0.5  0.167108
# 96  0.5  0.142874
# 97  0.5  0.163377
# 98  0.5  0.151673
# 99  0.5  0.134929
#
# [600 rows x 2 columns]

# %%
df0
# Out:
#       x        0%
# 0   1.0  0.000393
# 1   1.0  0.000539
# 2   1.0  0.000395
# 3   1.0  0.000687
# 4   1.0  0.000405
# ..  ...       ...
# 95  0.5  0.156648
# 96  0.5  0.136016
# 97  0.5  0.152710
# 98  0.5  0.146512
# 99  0.5  0.133318
#
# [600 rows x 2 columns]

# %%
fig, ax1 = plt.subplots(1, figsize=(16,12))
sb.lineplot(data=df_list[0], x='x', y='0%', label='0%')
sb.lineplot(data=df_list[1], x='x', y='15%', label='15%')
sb.lineplot(data=df_list[2], x='x', y='25%', label='25%')
sb.lineplot(data=df_list[3], x='x', y='35%', label='35%')
sb.lineplot(data=df_list[4], x='x', y='45%', label='45%')
sb.lineplot(data=df_list[5], x='x', y='55%', label='55%')
#sb.lineplot(data=df_list[6], x='x', y='65%', label='65%')
#sb.lineplot(data=df_list[7], x='x', y='75%', label='75%')
#sb.lineplot(data=df_list[8], x='x', y='85%', label='85%')
#sb.lineplot(data=df_list[9], x='x', y='90%', label='90%')
#sb.lineplot(data=df_list[10], x='x', y='91%', label='91%')
#sb.lineplot(data=df_list[11], x='x', y='92%', label='92%')
#sb.lineplot(data=df_list[12], x='x', y='93%', label='93%')
#sb.lineplot(data=df_list[13], x='x', y='94%', label='94%')
#sb.lineplot(data=df_list[14], x='x', y='95%', label='95%')
#sb.lineplot(data=df_list[16], x='x', y='97%', label='97%')
#sb.lineplot(data=df_list[17], x='x', y='98%', label='98%')

fig.gca().invert_xaxis()
ax1.legend()

# %%
fig, ax1 = plt.subplots(1, figsize=(16,10))
l1 =ax1.plot(x['0%'],label='0%')
l2=ax1.plot(x['15%'],label='15%')
l3=ax1.plot(x['25%'],label='25%')
l4=ax1.plot(x['35%'],label='35%')
l5=ax1.plot(x['45%'],label='45%')
l6=ax1.plot(x['55%'],label='55%')
l7=ax1.plot(x['65%'],label='65%')
l8=ax1.plot(x['75%'],label='75%')
l9=ax1.plot(x['85%'],label='85%')
#l10=ax1.plot(x['90%'])
#l11=ax1.plot(x['91%'])
#l12=ax1.plot(x['92%'])
#l13=ax1.plot(x['93%'])
#l14=ax1.plot(x['94%'])
#l15=ax1.plot(x['95%'])
#l16=ax1.plot(x['96%'])
#l17=ax1.plot(x['97%'])
#l18=ax1.plot(x['98%'])

ax1.set_ylabel('Loss')
ax1.set_xlabel('Scale')
ax1.set_xticklabels(['0','1', '0.9', '0.8', '0.7','0.6', '0.5'])

ax1.legend()
#ax1.legend([l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12,l13,l14,l15,l16,l17,l18],['0%', '15%', '25%', '35%', '45%', '55%', '65%', '75%', '85%', '90%', '91%', '92%', '93%', '94%', '95%', '96%', '97%', '98%' ])
